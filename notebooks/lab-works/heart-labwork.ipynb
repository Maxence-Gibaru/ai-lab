# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
df = pd.read_csv('../data/heart.csv', sep=',', header=0)
df.drop("id", axis=1, inplace=True)

df.head(), df.shape, df.columns
# Out:
# (   age  sex  cpt  bps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
#  0   63    1    3  145   233    1        0      150      0      2.3      0   0
#  1   37    1    2  130   250    0        1      187      0      3.5      0   0
#  2   41    0    1  130   204    0        0      172      0      1.4      2   0
#  3   56    1    1  120   236    0        1      178      0      0.8      2   0
#  4   57    0    0  120   354    0        1      163      1      0.6      2   0
#
#     thal  target
#  0     1       1
#  1     2       1
#  2     2       1
#  3     2       1
#  4     2       1  ,
#  (303, 14),
#  Index(['age', 'sex', 'cpt', 'bps', 'chol', 'fbs', 'restecg', 'thalach',
#         'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#        dtype='object'))

# %%
index_train = int(df.shape[0] * 0.8)

train_data = df[:index_train]
test_data = df[index_train:]

# %%
torch.Tensor(train_data.values)[0]
# Out:
# tensor([ 63.0000,   1.0000,   3.0000, 145.0000, 233.0000,   1.0000,   0.0000,
#         150.0000,   0.0000,   2.3000,   0.0000,   0.0000,   1.0000,   1.0000])

# %%
X_train = torch.Tensor(train_data.drop(labels="target", axis=1).values)
X_train = F.normalize(X_train)

Y_train = torch.Tensor(train_data['target'].values)
Y_train = Y_train.reshape(-1, 1)


X_test = torch.Tensor(test_data.drop(labels="target", axis=1).values)
X_test = F.normalize(X_test)

Y_test = torch.Tensor(test_data['target'].values)
Y_test = Y_test.reshape(-1, 1)

# %%
learning_rate = 0.001

# %%
class MLP(nn.Module):
    def __init__(self, input_dim=13, output_dim=1):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, 32)  
        self.act1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(32, 16)        
        self.act2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(16, output_dim)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        x = self.act1(self.fc1(x))
        #x = self.dropout1(x)
        x = self.act2(self.fc2(x))
        #x = self.dropout2(x)
        x = self.sigmoid(self.fc3(x))
        return x
model = MLP()


criterion = nn.BCELoss()
optimizer = optim.Adam(params=model.parameters(), lr=learning_rate)

# %%
# 2. Boucle d'entraînement avec monitoring
model = MLP()
criterion = nn.BCELoss()
optimizer = optim.Adam(params=model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(10000):
    # === TRAINING ===
    model.train()
    optimizer.zero_grad()
    
    predict_train = model(X_train)
    loss_train = criterion(predict_train, Y_train)
    loss_train.backward()
    optimizer.step()
    
    # Calculer l'accuracy train
    with torch.no_grad():
        pred_class_train = (predict_train >= 0.5).float()
        acc_train = (pred_class_train == Y_train).float().mean().item()
    

    # Sauvegarder les métriques
    train_losses.append(loss_train.item())
    train_accs.append(acc_train)
    
    
    # Afficher tous les 500 epochs
    if epoch % 100 == 0:
        print(f'Epoch {epoch}:')
        print(f'  Train - Loss: {loss_train.item():.4f}, Acc: {acc_train:.4f}')
        print()

# 3. Visualiser les courbes d'apprentissage
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Loss
ax1.plot(train_losses, label='Train Loss', alpha=0.7)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Loss pendant l\'entraînement')
ax1.legend()
ax1.grid(True)

# Accuracy
ax2.plot(train_accs, label='Train Acc', alpha=0.7)
ax2.plot(val_accs, label='Val Acc', alpha=0.7)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_title('Accuracy pendant l\'entraînement')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# 4. Métriques détaillées à la fin
from sklearn.metrics import classification_report, confusion_matrix

model.eval()
with torch.no_grad():
    pred_test = model(X_test)
    pred_class_test = (pred_test >= 0.5).float()

Y_test = torch.Tensor(test_data['target'].values).reshape(-1, 1)

print("\n=== RÉSULTATS FINAUX ===")
print("\nConfusion Matrix:")
print(confusion_matrix(Y_test.numpy(), pred_class_test.numpy()))
print("\nClassification Report:")
print(classification_report(Y_test.numpy(), pred_class_test.numpy()))
# Out:
# Epoch 0:
#   Train - Loss: 0.6753, Acc: 0.6818
#
# Epoch 100:
#   Train - Loss: 0.6241, Acc: 0.6818
#
# Epoch 200:
#   Train - Loss: 0.6177, Acc: 0.6818
#
# Epoch 300:
#   Train - Loss: 0.5992, Acc: 0.6818
#
# Epoch 400:
#   Train - Loss: 0.5441, Acc: 0.7438
#
# Epoch 500:
#   Train - Loss: 0.5030, Acc: 0.7521
#
# Epoch 600:
#   Train - Loss: 0.4711, Acc: 0.7686
#
# Epoch 700:
#   Train - Loss: 0.4182, Acc: 0.8306
#
# Epoch 800:
#   Train - Loss: 0.3622, Acc: 0.8512
#
# Epoch 900:
#   Train - Loss: 0.3286, Acc: 0.8719
#
# Epoch 1000:
#   Train - Loss: 0.3118, Acc: 0.8843
#
# Epoch 1100:
#   Train - Loss: 0.3041, Acc: 0.8884
#
# Epoch 1200:
#   Train - Loss: 0.3000, Acc: 0.8884
#
# Epoch 1300:
#   Train - Loss: 0.2975, Acc: 0.8884
#
# Epoch 1400:
#   Train - Loss: 0.2959, Acc: 0.8884
#
# Epoch 1500:
#   Train - Loss: 0.2945, Acc: 0.8884
#
# Epoch 1600:
#   Train - Loss: 0.2933, Acc: 0.8884
#
# Epoch 1700:
#   Train - Loss: 0.2924, Acc: 0.8884
#
# Epoch 1800:
#   Train - Loss: 0.2916, Acc: 0.8884
#
# Epoch 1900:
#   Train - Loss: 0.2911, Acc: 0.8884
#
# Epoch 2000:
#   Train - Loss: 0.2904, Acc: 0.8884
#
# Epoch 2100:
#   Train - Loss: 0.2899, Acc: 0.8884
#
# Epoch 2200:
#   Train - Loss: 0.2895, Acc: 0.8884
#
# Epoch 2300:
#   Train - Loss: 0.2891, Acc: 0.8884
#
# Epoch 2400:
#   Train - Loss: 0.2887, Acc: 0.8884
#
# Epoch 2500:
#   Train - Loss: 0.2883, Acc: 0.8884
#
# Epoch 2600:
#   Train - Loss: 0.2879, Acc: 0.8884
#
# Epoch 2700:
#   Train - Loss: 0.2876, Acc: 0.8884
#
# Epoch 2800:
#   Train - Loss: 0.2871, Acc: 0.8884
#
# Epoch 2900:
#   Train - Loss: 0.2867, Acc: 0.8884
#
# Epoch 3000:
#   Train - Loss: 0.2862, Acc: 0.8884
#
# Epoch 3100:
#   Train - Loss: 0.2858, Acc: 0.8884
#
# Epoch 3200:
#   Train - Loss: 0.2853, Acc: 0.8884
#
# Epoch 3300:
#   Train - Loss: 0.2849, Acc: 0.8884
#
# Epoch 3400:
#   Train - Loss: 0.2845, Acc: 0.8926
#
# Epoch 3500:
#   Train - Loss: 0.2840, Acc: 0.8926
#
# Epoch 3600:
#   Train - Loss: 0.2835, Acc: 0.8926
#
# Epoch 3700:
#   Train - Loss: 0.2829, Acc: 0.8926
#
# Epoch 3800:
#   Train - Loss: 0.2823, Acc: 0.8926
#
# Epoch 3900:
#   Train - Loss: 0.2818, Acc: 0.8926
#
# Epoch 4000:
#   Train - Loss: 0.2810, Acc: 0.8926
#
# Epoch 4100:
#   Train - Loss: 0.2803, Acc: 0.8926
#
# Epoch 4200:
#   Train - Loss: 0.2796, Acc: 0.8926
#
# Epoch 4300:
#   Train - Loss: 0.2788, Acc: 0.8926
#
# Epoch 4400:
#   Train - Loss: 0.2781, Acc: 0.8926
#
# Epoch 4500:
#   Train - Loss: 0.2773, Acc: 0.8926
#
# Epoch 4600:
#   Train - Loss: 0.2767, Acc: 0.8926
#
# Epoch 4700:
#   Train - Loss: 0.2758, Acc: 0.8926
#
# Epoch 4800:
#   Train - Loss: 0.2751, Acc: 0.8926
#
# Epoch 4900:
#   Train - Loss: 0.2744, Acc: 0.8926
#
# Epoch 5000:
#   Train - Loss: 0.2736, Acc: 0.8926
#
# Epoch 5100:
#   Train - Loss: 0.2728, Acc: 0.8926
#
# Epoch 5200:
#   Train - Loss: 0.2720, Acc: 0.8926
#
# Epoch 5300:
#   Train - Loss: 0.2714, Acc: 0.8926
#
# Epoch 5400:
#   Train - Loss: 0.2701, Acc: 0.8926
#
# Epoch 5500:
#   Train - Loss: 0.2690, Acc: 0.8926
#
# Epoch 5600:
#   Train - Loss: 0.2681, Acc: 0.8926
#
# Epoch 5700:
#   Train - Loss: 0.2670, Acc: 0.8926
#
# Epoch 5800:
#   Train - Loss: 0.2660, Acc: 0.8967
#
# Epoch 5900:
#   Train - Loss: 0.2652, Acc: 0.8926
#
# Epoch 6000:
#   Train - Loss: 0.2643, Acc: 0.8967
#
# Epoch 6100:
#   Train - Loss: 0.2633, Acc: 0.9050
#
# Epoch 6200:
#   Train - Loss: 0.2626, Acc: 0.9050
#
# Epoch 6300:
#   Train - Loss: 0.2617, Acc: 0.9050
#
# Epoch 6400:
#   Train - Loss: 0.2610, Acc: 0.9050
#
# Epoch 6500:
#   Train - Loss: 0.2601, Acc: 0.9050
#
# Epoch 6600:
#   Train - Loss: 0.2595, Acc: 0.9050
#
# Epoch 6700:
#   Train - Loss: 0.2586, Acc: 0.9050
#
# Epoch 6800:
#   Train - Loss: 0.2578, Acc: 0.9050
#
# Epoch 6900:
#   Train - Loss: 0.2573, Acc: 0.9050
#
# Epoch 7000:
#   Train - Loss: 0.2564, Acc: 0.9050
#
# Epoch 7100:
#   Train - Loss: 0.2559, Acc: 0.9050
#
# Epoch 7200:
#   Train - Loss: 0.2552, Acc: 0.9091
#
# Epoch 7300:
#   Train - Loss: 0.2541, Acc: 0.9050
#
# Epoch 7400:
#   Train - Loss: 0.2533, Acc: 0.9091
#
# Epoch 7500:
#   Train - Loss: 0.2525, Acc: 0.9091
#
# Epoch 7600:
#   Train - Loss: 0.2520, Acc: 0.9091
#
# Epoch 7700:
#   Train - Loss: 0.2511, Acc: 0.9091
#
# Epoch 7800:
#   Train - Loss: 0.2507, Acc: 0.9091
#
# Epoch 7900:
#   Train - Loss: 0.2498, Acc: 0.9132
#
# Epoch 8000:
#   Train - Loss: 0.2492, Acc: 0.9132
#
# Epoch 8100:
#   Train - Loss: 0.2485, Acc: 0.9132
#
# Epoch 8200:
#   Train - Loss: 0.2478, Acc: 0.9132
#
# Epoch 8300:
#   Train - Loss: 0.2472, Acc: 0.9132
#
# Epoch 8400:
#   Train - Loss: 0.2466, Acc: 0.9174
#
# Epoch 8500:
#   Train - Loss: 0.2452, Acc: 0.9215
#
# Epoch 8600:
#   Train - Loss: 0.2435, Acc: 0.9174
#
# Epoch 8700:
#   Train - Loss: 0.2420, Acc: 0.9174
#
# Epoch 8800:
#   Train - Loss: 0.2400, Acc: 0.9132
#
# Epoch 8900:
#   Train - Loss: 0.2382, Acc: 0.9215
#
# Epoch 9000:
#   Train - Loss: 0.2363, Acc: 0.9174
#
# Epoch 9100:
#   Train - Loss: 0.2344, Acc: 0.9215
#
# Epoch 9200:
#   Train - Loss: 0.2325, Acc: 0.9174
#
# Epoch 9300:
#   Train - Loss: 0.2303, Acc: 0.9174
#
# Epoch 9400:
#   Train - Loss: 0.2290, Acc: 0.9215
#
# Epoch 9500:
#   Train - Loss: 0.2265, Acc: 0.9174
#
# Epoch 9600:
#   Train - Loss: 0.2246, Acc: 0.9174
#
# Epoch 9700:
#   Train - Loss: 0.2225, Acc: 0.9174
#
# Epoch 9800:
#   Train - Loss: 0.2203, Acc: 0.9215
#
# Epoch 9900:
#   Train - Loss: 0.2182, Acc: 0.9298
# === RÉSULTATS FINAUX ===
#
# Confusion Matrix:
# [[37 24]
#  [ 0  0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.61      0.76        61
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.61        61
#    macro avg       0.50      0.30      0.38        61
# weighted avg       1.00      0.61      0.76        61
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MLP                                      --
# ├─Linear: 1-1                            448
# ├─ReLU: 1-2                              --
# ├─Dropout: 1-3                           --
# ├─Linear: 1-4                            528
# ├─ReLU: 1-5                              --
# ├─Dropout: 1-6                           --
# ├─Linear: 1-7                            17
# ├─Sigmoid: 1-8                           --
# =================================================================
# Total params: 993
# Trainable params: 993
# Non-trainable params: 0
# =================================================================

# %%
# 4. Métriques détaillées à la fin
from sklearn.metrics import classification_report, confusion_matrix

model.eval()
with torch.no_grad():
    pred_test = model(X_test)
    pred_class_test = (pred_test >= 0.5).float()
    acc_test = (pred_class_test == Y_test).float().mean().item()

print("acc_test :", np.round(acc_test * 100, 2), "%")

print("\n=== RÉSULTATS FINAUX ===")
print("\nConfusion Matrix:")
print(confusion_matrix(Y_test.numpy(), pred_class_test.numpy()))
print("\nClassification Report:")
print(classification_report(Y_test.numpy(), pred_class_test.numpy()))
# Out:
# acc_test : 60.66 %
#
# === RÉSULTATS FINAUX ===
#
# Confusion Matrix:
# [[37 24]
#  [ 0  0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.61      0.76        61
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.61        61
#    macro avg       0.50      0.30      0.38        61
# weighted avg       1.00      0.61      0.76        61
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
